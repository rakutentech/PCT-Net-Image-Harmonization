# %% [markdown]
# # Evaluation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load data from csv files

# %%
# Composite Error
df_comp = pd.read_csv('evaluation_composite.csv')
df_comp = df_comp.sort_values(by='Name')
# Harmonizer
df = pd.read_csv('evaluation_harmonizer.csv')
df_harm = df.sort_values(by='Name')
# DCCF
df = pd.read_csv('evaluation_DCCF.csv')
df_dccf = df.sort_values(by='Name')
# PCTNet CNN
df = pd.read_csv('evaluation_PCTNet_CNN.csv')
df_ours_CNN = df.sort_values(by='Name')
# PCTNet ViT
df = pd.read_csv('evaluation_PCTNet_ViT.csv')
df_ours_ViT = df.sort_values(by='Name')

# %% [markdown]
# ## Evaluation fMSE, PSNR, MSE, SE

# %%
def evaluate(df):
    print(f"fMSE: {np.mean(df['fMSE']):.2f} (+/-{np.std(df['fMSE']):.2f})")
    print(f"PSNR: {np.mean(df['PSNR']):.2f} (+/-{np.std(df['PSNR']):.2f})")
    print(f"MSE: {np.mean(df['MSE']):.2f} (+/-{np.std(df['MSE']):.2f})")
    print(f"SE: {np.mean(df['SE']):.2f} (+/-{np.std(df['SE']):.2f})")

# %%
evaluate(df_comp)
# Out:
# fMSE: 1462.45 (+/-1638.06)
# PSNR: 31.39 (+/-7.02)
# MSE: 177.99 (+/-425.09)
# SE: 2958.43 (+/-10335.97)

# %%
evaluate(df_ours_ViT)
# Out:
# fMSE: 237.49 (+/-298.93)
# PSNR: 39.29 (+/-5.53)
# MSE: 18.84 (+/-47.17)
# SE: 190.49 (+/-981.59)

# %%
evaluate(df_ours_CNN)
# Out:
# fMSE: 282.75 (+/-323.49)
# PSNR: 38.30 (+/-5.63)
# MSE: 24.02 (+/-55.50)
# SE: 215.06 (+/-930.69)

# %%
evaluate(df_dccf)
# Out:
# fMSE: 302.56 (+/-342.24)
# PSNR: 38.01 (+/-5.53)
# MSE: 24.72 (+/-51.73)
# SE: 226.54 (+/-780.98)

# %%
evaluate(df_harm)
# Out:
# fMSE: 339.20 (+/-382.93)
# PSNR: 37.23 (+/-5.62)
# MSE: 27.62 (+/-57.73)
# SE: 2149.56 (+/-6231.62)

# %% [markdown]
# ## Alternative Metrics

# %%
def create_addtional_columns(df, df_comp):
    df['MSE_comp'] = df_comp['MSE']
    df['fMSE_comp'] = df_comp['fMSE']
    df['PSNR_comp'] = df_comp['PSNR']
    df['MSE_diff'] = df['MSE'] - df['MSE_comp']
    df['fMSE_diff'] = df['fMSE'] - df['fMSE_comp']
    df['PSNR_diff'] = df['PSNR'] - df['PSNR_comp'] 

    def f(row):
        if row['Name'][0] == 'a':
            return 'HAdobe5k'
        elif row['Name'][0] == 'f':
            return 'HFlickr'
        elif row['Name'][0] == 'c':
            return 'HCOCO'
        elif row['Name'][0] == 'd':
            return 'Hday2night'
    df['Dataset'] = df.apply(f, axis=1)
    return df

# %%
df_ours_ViT = create_addtional_columns(df_ours_ViT, df_comp)
df_ours_CNN = create_addtional_columns(df_ours_CNN, df_comp)
df_dccf = create_addtional_columns(df_dccf, df_comp)
df_harm = create_addtional_columns(df_harm, df_comp)

# %% [markdown]
# Data exploration using different metrics is possible. For example, 20 worst harmonization results by fMSE:

# %%
df_ours_ViT.sort_values(by='fMSE')[-20:]
# Out:
#                             Name          MSE       PSNR         fMSE  \
# 7334           d90000012-181_1_7    50.366405  31.109394  2430.560547
# 7290  d18897-20120428-164138_1_2    33.791149  32.842774  2483.406982
# 6580                   f5161_1_2     6.983235  39.690236  2491.846191
# 6494                    f108_1_2   116.577835  27.464644  2511.050537
# 7177                   f2690_1_2  1279.668335  17.059829  2527.803711
# 6634                   f4552_1_1    14.315855  36.572630  2608.073730
# 6444                   f2508_1_1    14.497422  36.517895  2837.961670
# 5923           c360951_1097742_1   174.701401  25.707840  2915.785156
# 6581                   f5161_1_1     8.413094  38.881246  3002.066650
# 7271   d1048-20120628-200951_1_3    16.902056  35.851408  3044.899170
# 6445                   f2508_1_2    15.817814  36.139339  3096.436523
# 4129             c25057_602133_1    55.097691  30.719470  3162.471436
# 1437                   a1524_1_2   944.591980  18.378361  3203.482178
# 6615                   f4469_1_2    14.783260  36.433101  3235.073242
# 4481            c437522_137270_1    38.464527  32.280200  3302.821045
# 651                    a2865_1_1    35.790993  32.593066  3307.048340
# 1439                   a1524_1_5   999.739807  18.131934  3390.510010
# 7378  d17664-20120114-145839_1_8  1044.585449  17.941364  4354.683594
# 6459                   f2927_1_2    29.415262  33.445076  5009.333984
# 7297            d90000004-18_1_1    41.835270  31.915378  5431.865723
#
#                 SE      SSIM  height  width     mask_area    MSE_comp  \
# 7334     46.200096  0.991845     480    637  6.336000e+03  871.717590
# 7290     31.141924  0.994061     480    640  4.180000e+03  184.658051
# 6580     14.652056  0.999188     683   1024  1.960000e+03    3.883795
# 6494    245.317072  0.980511     685   1024  3.256500e+04    0.799886
# 7177   3007.322880  0.943544     765   1024  3.965660e+05  135.555496
# 6634     30.037184  0.998143     683   1024  3.839000e+03   24.507875
# 6444     30.462680  0.998467     684   1024  3.578000e+03    4.209856
# 5923    143.227200  0.979228     427    640  1.637377e+04  267.295044
# 6581     17.652152  0.999035     683   1024  1.960000e+03    5.465471
# 7271     15.382831  0.997464     477    636  1.684000e+03  337.991150
# 6445     33.237150  0.998173     684   1024  3.578000e+03    8.847601
# 4129     45.171292  0.996498     427    640  4.761181e+03   82.014633
# 1437  34348.447744  0.957679    2848   4256  3.574074e+06  125.903381
# 6615     31.017882  0.997862     683   1024  3.196000e+03   43.968464
# 4481     35.448908  0.996528     480    640  3.577639e+03   26.048256
# 651     645.955840  0.996840    2000   3008  6.510900e+04   49.909321
# 1439  36353.802240  0.955738    2848   4256  3.574074e+06   56.360760
# 7378    962.689920  0.897861     480    640  7.369000e+04  336.266846
# 6459     69.399312  0.997853     768   1024  4.618000e+03    3.342739
# 7297     38.555384  0.996430     480    640  2.366000e+03   85.262955
#
#         fMSE_comp  PSNR_comp     MSE_diff    fMSE_diff  PSNR_diff     Dataset
# 7334  3217.138916  18.727046  -821.351185  -786.578369  12.382348  Hday2night
# 7290   831.959229  25.467121  -150.866901  1651.447754   7.375653  Hday2night
# 6580   187.671600  42.238239     3.099440  2304.174591  -2.548003     HFlickr
# 6494   171.240768  49.100515   115.777949  2339.809769 -21.635871     HFlickr
# 7177   866.080261  26.809632  1144.112839  1661.723450  -9.749803     HFlickr
# 6634   558.494324  34.237747   -10.192020  2049.579407   2.334884     HFlickr
# 6444   758.403992  41.888131    10.287567  2079.557678  -5.370235     HFlickr
# 5923  4461.182617  23.860895   -92.593643 -1545.397461   1.846945       HCOCO
# 6581  2120.081299  40.754527     2.947623   881.985352  -1.873281     HFlickr
# 7271  1257.965332  22.841750  -321.089094  1786.933838  13.009658  Hday2night
# 6445  1593.892090  38.662548     6.970213  1502.544434  -2.523209     HFlickr
# 4129  4707.437500  28.991890   -26.916943 -1544.966064   1.727579       HCOCO
# 1437   426.987793  27.130430   818.688599  2776.494385  -8.752069    HAdobe5k
# 6615  2165.705566  31.699391   -29.185204  1069.367676   4.733710     HFlickr
# 4481  2236.677002  33.973017    12.416271  1066.144043  -1.692817       HCOCO
# 651   4611.566406  31.148987   -14.118328 -1304.518066   1.444079    HAdobe5k
# 1439   191.141464  30.621035   943.379047  3199.368546 -12.489101    HAdobe5k
# 7378   970.165710  22.863963   708.318604  3384.517883  -4.922599  Hday2night
# 6459   739.618835  42.889778    26.072523  4269.715149  -9.444702     HFlickr
# 7297   360.148438  28.823200   -43.427685  5071.717285   3.092178  Hday2night

# %% [markdown]
# # Percentage of Improvements by Metrics

# %%
def classification_eval(df, metric):
    print(f'Improvement of {metric}')
    out_title = 'All\t|\t'
    out_str = f"{len(df[df[metric] < 0])/len(df)*100:.2f}%\t|\t"
    for ds in ['HCOCO', 'HFlickr',  'HAdobe5k', 'Hday2night']:
        df_ds = df[df['Dataset']==ds]
        out_title += f'{ds}\t|\t' 
        out_str += f'{len(df_ds[df_ds[metric]<0])/len(df_ds)*100:.2f}%\t|\t'
        if ds in ['HAdobe5k', 'Hday2night']:
            out_title = out_title[:-3] + '|\t'
    print(out_title)
    print(out_str)

# %%
classification_eval(df_ours_ViT, 'fMSE_diff')
classification_eval(df_ours_ViT, 'PSNR_diff')
classification_eval(df_ours_ViT, 'MSE_diff')
# Out:
# Improvement of fMSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 95.11%	|	96.52%	|	86.96%	|	96.71%	|	74.44%	|
# Improvement of PSNR_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 5.73%	|	3.48%	|	23.43%	|	3.29%	|	7.52%	|
# Improvement of MSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 94.27%	|	96.52%	|	76.57%	|	96.71%	|	92.48%	|

# %%
classification_eval(df_ours_CNN, 'fMSE_diff')
classification_eval(df_ours_CNN, 'PSNR_diff')
classification_eval(df_ours_CNN, 'MSE_diff')
# Out:
# Improvement of fMSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 88.48%	|	88.77%	|	76.69%	|	93.38%	|	72.93%	|
# Improvement of PSNR_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 26.18%	|	27.71%	|	57.25%	|	12.27%	|	9.02%	|
# Improvement of MSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 73.82%	|	72.29%	|	42.75%	|	87.73%	|	90.98%	|

# %%
classification_eval(df_harm, 'fMSE_diff')
classification_eval(df_harm, 'PSNR_diff')
classification_eval(df_harm, 'MSE_diff')
# Out:
# Improvement of fMSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 85.67%	|	84.45%	|	74.76%	|	92.92%	|	75.19%	|
# Improvement of PSNR_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 27.70%	|	28.16%	|	58.21%	|	16.57%	|	3.76%	|
# Improvement of MSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 73.26%	|	71.87%	|	41.91%	|	86.62%	|	96.24%	|

# %%
classification_eval(df_dccf, 'fMSE_diff')
classification_eval(df_dccf, 'PSNR_diff')
classification_eval(df_dccf, 'MSE_diff')
# Out:
# Improvement of fMSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 93.76%	|	93.86%	|	91.55%	|	95.19%	|	81.20%	|
# Improvement of PSNR_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 6.24%	|	6.14%	|	8.45%	|	4.81%	|	18.80%	|
# Improvement of MSE_diff
# All	|	HCOCO	|	HFlickr	|	HAdobe5k|	Hday2night|
# 93.76%	|	93.86%	|	91.55%	|	95.19%	|	81.20%	|
